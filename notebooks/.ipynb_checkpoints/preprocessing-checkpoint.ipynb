# %% [markdown]
# # Preprocessing

# %% [markdown]
# ***
# ## Notes

# %% [markdown]
#  - Do we need to first detect clouds and ice in the image?
#  - GSw: use max_extent or another metric?
#  - Remove points overlying permanent water from classifier? Or remove later?
#  - Height Above Nearest Drainage ([HAND](https://www.mdpi.com/2072-4292/8/5/386)) data useful for separating areas where water is more or less likely to occur

# %%
# %matplotlib inline
import ipywidgets
import IPython.display
import numpy as np
import pprint
import pandas as pd
import matplotlib.pyplot as plt
import ee; ee.Initialize()

# Configure the pretty printing output
pp = pprint.PrettyPrinter(depth=4)

# %% [markdown]
# ## Image acquisition

# %%
# Landsat 8 scene from Iowa City, IA (2016)
scene = ee.Image('LANDSAT/LC08/C01/T1_TOA/LC08_025031_20160926')

# Get metadata
# scene.getInfo()

# Rename bands to something more understandable
l8t1_bands = ee.Dictionary({
    'B1': 'ultra_blue',
    'B2': 'blue',
    'B3': 'green',
    'B4': 'red',
    'B5': 'nir',
    'B6': 'swir1',
    'B7': 'swir2',
    'B8': 'pan',
    'B9': 'cirrus',
    'B10': 'tirs1',
    'B11': 'tirs2',
    'BQA': 'bqa'
})
band_names_new = l8t1_bands.values(scene.bandNames())
band_names_original = scene.bandNames()
scene = scene.select(band_names_original, band_names_new)

# Get metadata
# scene.getInfo()

# %% [markdown]
# ## Pansharpen and visualize the scene in true color

# %%
# Visualize part of image in RGB
poly = ee.Geometry.Polygon(
    [[[-91.78812019737575, 41.95033307316587],
           [-91.79361336143825, 41.90333364712244],
           [-91.71739571007106, 41.9012894084067],
           [-91.72151558311793, 41.95288639774597]]])

# parameters for stretching
visparams = {'bands': 'red,green,blue', 
             'min': 0,
             'max': 0.25,
             'region':poly.getInfo()['coordinates']}

url = scene.getThumbUrl(visparams) 
IPython.display.Image(url=url, format='png', embed=True)

# %%
# Pansharpen the image to get a better resolution
def panSharpenL8(scene):
    hsv = scene.select('red', 'green', 'blue').rgbToHsv()
    sharpened = ee.Image.cat([hsv.select('hue'), 
                              hsv.select('saturation'), 
                              image.select('pan')]).hsvToRgb()
    return sharpened

# parameters for stretching
visparams = {'min':0,
             'max': 0.25,
             'gamma': [1.3, 1.3, 1.3],
             'region':poly.getInfo()['coordinates']}

sharpened = panSharpenL8(scene)

# Get thumbnail URL from GEE server
url = sharpened.getThumbUrl(visparams) 
IPython.display.Image(url=url, format='png', embed=True)

# %% [markdown]
# ## Dataset Inventory:

# %% [markdown]
#   - SRTM 30m DEM
#       - aspect: GEE
#       - slope: GEE
#       - curvature: Python package using np arrays? Or get DEM ascii and use ArcGIS jupyter notebook to calculate
#       - SPI: Python?
#       - TWI: Python?
#   - Land cover
#   - Distance from permanent water extent
#   - Lithography

# %% [markdown]
# ## Detect inundation

# %%
# Calculate MNDWI
# This should eventually be done with a ML classifier if it's better - What did Dartmouth use? Ask Sam.

mndwi = scene.normalizedDifference(['green','swir2']).rename('mndwi') # L8, renamed 

def thresh(scene):
#     histogram = ndwi.reduceRegion(ee.Reducer.histogram(50).combine('mean', 'mean', True).combine('variance', 'var', True), polygon.buffer(1500), 100, None, None, True)
    histogram = scene.reduceRegion(ee.Reducer.histogram(50).combine('mean', None, True).combine('variance', None, True), None, 100, None, None, True)
    histogram = histogram.get('mndwi_histogram')

    def otsu(histogram):
        counts = ee.Array(ee.Dictionary(histogram).get('histogram'))
        means = ee.Array(ee.Dictionary(histogram).get('bucketMeans'))
        size = means.length().get([0])
        total = counts.reduce(ee.Reducer.sum(), [0]).get([0])
        sums = means.multiply(counts).reduce(ee.Reducer.sum(), [0]).get([0])
        mean = sums.divide(total)
        indices = ee.List.sequence(1, size)
  
  ### Compute between sum of squares, where each mean partitions the data.
        def ss(i):
            aCounts = counts.slice(0, 0, i)
            aCount = aCounts.reduce(ee.Reducer.sum(), [0]).get([0]);
            aMeans = means.slice(0, 0, i);
            aMean = aMeans.multiply(aCounts).reduce(ee.Reducer.sum(), [0]).get([0]).divide(aCount)
            bCount = total.subtract(aCount)
            bMean = sums.subtract(aCount.multiply(aMean)).divide(bCount)
            return aCount.multiply(aMean.subtract(mean).pow(2)).add(bCount.multiply(bMean.subtract(mean).pow(2)))
        
        bss = indices.map(ss)
        return means.sort(bss).get([-1])

        #### Return the mean value corresponding to the maximum BSS.
    threshold = otsu(histogram)
#     return scene.addBands(ndwi).set({'threshold': threshold}) # threshold is a property of the ndwi band of this image, don't know how to get this computedobject though so we will just return the number itself for now
#     will eventually probs want to do the image thresholding on server side and not use getInfo, to speed up computation if need be
    return threshold # this is the otsu threshold

# #============= With entire MNDWI
# scene_threshed = thresh(mndwi)
# threshold = scene_threshed.getInfo()

# url = mndwi.select('mndwi').lt(threshold).getThumbUrl()
# # url = scene_threshed.select('mndwi').lt('threshold').getThumbUrl()
# IPython.display.Image(url=url, format='png', embed=True)

#============= With dilated MNDWI

# Canny edge detection
canny = ee.Algorithms.CannyEdgeDetector(mndwi, 0.99, 0)

# Now adding a buffer (morphological dilation) to the edges equal to 1/2 the pixel size (30m / 2  = 15m). 
# Might want to tune this parameter

# Define a kernel (structuring element)
kernel = ee.Kernel.square(radius = 0.5, units = 'pixels')

# Dilate
buffered = canny.focal_max(kernel = kernel, iterations = 2)

# Mask MNDWI
mndwi_mask = mndwi.mask(buffered)

threshold = thresh(mndwi_mask).getInfo()
threshold

# Threshold water from non-water
water = mndwi.gt(threshold)

# %% [markdown]
# ## Fetch auxiliary datasets

# %%
DEM = ee.Image("USGS/NED") # 10-m DEM from USGS National Elevation Dataset

# Permanent Water Extent, Joint Research Centre, Global Surface Water dataset (JRC GSW)
GSW = ee.Image('JRC/GSW1_0/GlobalSurfaceWater') # Permanent Water Extent, Joint Research Centre, Global Surface Water dataset (JRC GSW)
GSW_trans = GSW.select(5) # Band 5 ("transition") has a permanent water code, 1
GSW_perm = GSW_trans.lt(2).gt(0) # Get only permanent water extent, code 1

nlcd = ee.Image('USGS/NLCD/NLCD2011') # NLCD: National Land Cover Dataset

# National Hydrography Dataset (NHD)

lith = ee.Image("CSP/ERGo/1_0/US/lithology") # US lithology

# # Look at HydroSHEDS data here 
# # https://developers.google.com/earth-engine/datasets/tags/hydrology
# # all HydroSHEDS datasets available in 3, 15 and 30 arc-seconds 

# # WWF HydroSHEDS hydrologically conditioned DEM, 3 arc-seconds
# ee.Image("WWF/HydroSHEDS/03CONDEM")

# # WWF HydroSHEDS flow accumulation, 15 arc-seconds
# ee.Image("WWF/HydroSHEDS/15ACC")

# # WWF HydroSHEDS drainage direction, 3 arc-seconds
# ee.Image("WWF/HydroSHEDS/03DIR")

# %% [markdown]
# ## Calculate derived datasets

# %%
# Slope
slope = ee.Terrain.slope(DEM)

# Aspect
aspect = ee.Terrain.aspect(DEM)

# TWI, SPI, etc.?

# Distance from permanent water extent
dist = GSW_perm.fastDistanceTransform() # distance from permanent water bodies

# %% [markdown]
# ## Cloudmask

# %%
ic = ee.ImageCollection('LANDSAT/LC8_L1T_TOA_FMASK')
# var image = ee.Image('LANDSAT/LC08/C01/T1_TOA/LC08_025031_20160926')

# The geometry is used to find an L8 image. 
# Unsure as to whether this should be a point in the actual scene, or just any random point anywhere.
geometry = ee.Geometry.Point([-91.31451760101419, 41.881010150388526]);

c = ic.filterBounds(geometry) # Filter collection to this area

cloud = ee.Algorithms.Landsat.simpleCloudScore(scene).select('cloud')
cloudiness = cloud.reduceRegion(ee.Reducer.mean(), geometry, 30)

# %%
# Getting images with X% cloudcover and taking their fmask to use as the cloudmask for our scene of interest

# A polygon representing the roi.
ic = ee.ImageCollection('LANDSAT/LC8_L1T_TOA_FMASK')
# var image = ee.Image('LANDSAT/LC08/C01/T1_TOA/LC08_025031_20160926')

# The geometry is used to find an L8 image. 
# Unsure as to whether this should be a point in the actual scene, or just any random point anywhere.
geometry = ee.Geometry.Point([-91.31451760101419, 41.881010150388526])

c = ic.filterBounds(geometry) # Filter collection to this area

# Do we need a geometry? Or can we just filter only by cloudscore? What exactly is this used for?
def getCloudScore(image):
    cloud = ee.Algorithms.Landsat.simpleCloudScore(scene).select('cloud')
    cloudiness = cloud.reduceRegion(ee.Reducer.mean(), geometry, 30)
    return image.set(cloudiness)

# Find images with certain % of average cloud cover per pixel
# from: https://gis.stackexchange.com/questions/252685/filter-landsat-images-base-on-cloud-cover-over-a-region-of-interest/252785
withCloudiness = c.map(getCloudScore)

filteredCollection = withCloudiness.filter(ee.Filter.gt('cloud', 20))
filteredCollection = filteredCollection.filter(ee.Filter.lt('cloud', 30))

sortedCollection = filteredCollection.sort('DATE_ACQUIRED')
scene = ee.Image(sortedCollection.first())

# Fmask classification values
# from: https://medium.com/upstream/find-water-and-remove-clouds-with-fmask-on-google-earth-engine-261c090cb62d
FMASK_CLOUD = 4
FMASK_CLOUD_SHADOW = 2
fmask = scene.select('fmask')
cloudmask = fmask.neq(FMASK_CLOUD).And(fmask.neq(FMASK_CLOUD_SHADOW))

# %% [markdown]
# ## Stack images together

# %%
stack = DEM.addBands([GSW_perm, nlcd, lith, hydrosheds, cloudmask, water]) # Stack Datasets

# %%
# mytask = ee.batch.Export.scene.toDrive(clouds_arr, folder='data_earth_engine', description='myExportTableTask')
# ee.batch.data.startProcessing(mytask.id, mytask.config)

# %% [markdown]
# ## Extract values of randomly sampled points to a table

# %%
scene = ee.Image('LANDSAT/LC08/C01/T1_TOA/LC08_025031_20160926')
extent = scene.geometry() # create polygon of L8 scene extent

pts = ee.FeatureCollection.randomPoints(extent, 1000) # randomly sampled points
 
stack_sample = stack.reduceRegions(pts, ee.Reducer.first()) # extract values of image stack to points

# %% [markdown]
# ## Export table and download locally for use with TensorFlow

# %%
# Define some task properties as a dictionary
params = {'driveFolder': 'your_drive',  'driveFileNamePrefix': 'filename', 'fileFormat': 'CSV'}

# Define the task in Python
task = ee.batch.Export.table(stack_sample, 'taskname', params)

# Start the task, equivalent to hit the "run" button in the editor
task.start()
