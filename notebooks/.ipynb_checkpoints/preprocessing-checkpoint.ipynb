# %%
# %matplotlib inline
import ipywidgets
import IPython.display
import numpy as np
import pprint
import pandas as pd
import matplotlib.pyplot as plt
import ee; ee.Initialize()

# Configure the pretty printing output
pp = pprint.PrettyPrinter(depth=4)

# %%
def reduceImageProfile(image, line, reducer, scale):
    """Returns image values reduced along given line.

    Args:
        image: Image to be reduced.
        line: The line string used to query image values. The function splits
            the line into smaller segments with the length equal to scale.
            These smaller segments are then used to reduce image values with
            the reducer.
        reducer: Used used to reduce image values along line segments.
        scale: Indicates scale used to cut line into shorter line segment.

    Returns:
        An ee.FeatureCollection containing distance and iamge value properties. 
    """

    length = line.length()
    distances = ee.List.sequence(0, length, scale)
    lines = line.cutLines(distances).geometries()

    def generate_line_segment(l):
        l = ee.List(l)
        geom = ee.Geometry(l.get(0))
        distance = ee.Geometry(l.get(1))

        geom = ee.Algorithms.GeometryConstructors.LineString(geom.coordinates())

        return ee.Feature(geom, {'distance': distance})

    lines = lines.zip(distances).map(generate_line_segment)
    lines = ee.FeatureCollection(lines)

    # reduce image for every segment
    band_names = image.bandNames()

    return image.reduceRegions(lines, reducer.setOutputs(band_names), scale)

# %%
# image to be queried
image = ee.Image('USGS/NED')

# a line string used to qeury image values
line = ee.Geometry.LineString(
        [[-114.3843, 36.4257],
         [-114.3616, 36.4220],
         [-114.3514, 36.4203],
         [-114.3419, 36.4199],
         [-114.3116, 36.4228]])

# %%
profile = reduceImageProfile(image, line, reducer=ee.Reducer.max(), scale=10)

# fetch resulting features (line segments) to the client
features = profile.getInfo()['features']

# extract distance and elevation properties from the resulting feature collection
x = [f['properties'].get('distance') for f in features]
y = [f['properties'].get('elevation') for f in features]

# plot
fig, ax = plt.subplots(figsize=(13, 8))
ax.plot(x, y)

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ....

# %% [markdown]
# ## Image acquisition

# %%
image = ee.Image('LANDSAT/LC08/C01/T1_TOA/LC08_025031_20160926')

# %%
pp.pprint(image.getInfo())
# Out:
# {'bands': [{'crs': 'EPSG:32615',
#             'crs_transform': [30.0, 0.0, 518085.0, 0.0, -30.0, 4740915.0],
#             'data_type': {'precision': 'float', 'type': 'PixelType'},
#             'dimensions': [7681, 7801],
#             'id': 'B1'},
#            {'crs': 'EPSG:32615',
#             'crs_transform': [30.0, 0.0, 518085.0, 0.0, -30.0, 4740915.0],
#             'data_type': {'precision': 'float', 'type': 'PixelType'},
#             'dimensions': [7681, 7801],
#             'id': 'B2'},
#            {'crs': 'EPSG:32615',
#             'crs_transform': [30.0, 0.0, 518085.0, 0.0, -30.0, 4740915.0],
#             'data_type': {'precision': 'float', 'type': 'PixelType'},
#             'dimensions': [7681, 7801],
#             'id': 'B3'},
#            {'crs': 'EPSG:32615',
#             'crs_transform': [30.0, 0.0, 518085.0, 0.0, -30.0, 4740915.0],
#             'data_type': {'precision': 'float', 'type': 'PixelType'},
#             'dimensions': [7681, 7801],
#             'id': 'B4'},
#            {'crs': 'EPSG:32615',
#             'crs_transform': [30.0, 0.0, 518085.0, 0.0, -30.0, 4740915.0],
#             'data_type': {'precision': 'float', 'type': 'PixelType'},
#             'dimensions': [7681, 7801],
#             'id': 'B5'},
#            {'crs': 'EPSG:32615',
#             'crs_transform': [30.0, 0.0, 518085.0, 0.0, -30.0, 4740915.0],
#             'data_type': {'precision': 'float', 'type': 'PixelType'},
#             'dimensions': [7681, 7801],
#             'id': 'B6'},
#            {'crs': 'EPSG:32615',
#             'crs_transform': [30.0, 0.0, 518085.0, 0.0, -30.0, 4740915.0],
#             'data_type': {'precision': 'float', 'type': 'PixelType'},
#             'dimensions': [7681, 7801],
#             'id': 'B7'},
#            {'crs': 'EPSG:32615',
#             'crs_transform': [15.0, 0.0, 518092.5, 0.0, -15.0, 4740907.5],
#             'data_type': {'precision': 'float', 'type': 'PixelType'},
#             'dimensions': [15361, 15601],
#             'id': 'B8'},
#            {'crs': 'EPSG:32615',
#             'crs_transform': [30.0, 0.0, 518085.0, 0.0, -30.0, 4740915.0],
#             'data_type': {'precision': 'float', 'type': 'PixelType'},
#             'dimensions': [7681, 7801],
#             'id': 'B9'},
#            {'crs': 'EPSG:32615',
#             'crs_transform': [30.0, 0.0, 518085.0, 0.0, -30.0, 4740915.0],
#             'data_type': {'precision': 'float', 'type': 'PixelType'},
#             'dimensions': [7681, 7801],
#             'id': 'B10'},
#            {'crs': 'EPSG:32615',
#             'crs_transform': [30.0, 0.0, 518085.0, 0.0, -30.0, 4740915.0],
#             'data_type': {'precision': 'float', 'type': 'PixelType'},
#             'dimensions': [7681, 7801],
#             'id': 'B11'},
#            {'crs': 'EPSG:32615',
#             'crs_transform': [30.0, 0.0, 518085.0, 0.0, -30.0, 4740915.0],
#             'data_type': {'max': 65535,
#                           'min': 0,
#                           'precision': 'int',
#                           'type': 'PixelType'},
#             'dimensions': [7681, 7801],
#             'id': 'BQA'}],
#  'id': 'LANDSAT/LC08/C01/T1_TOA/LC08_025031_20160926',
#  'properties': {'BPF_NAME_OLI': 'LO8BPF20160926163817_20160926172232.01',
#                 'BPF_NAME_TIRS': 'LT8BPF20160917100055_20161002083254.01',
#                 'CLOUD_COVER': 0.01,
#                 'CLOUD_COVER_LAND': 0.01,
#                 'COLLECTION_CATEGORY': 'T1',
#                 'COLLECTION_NUMBER': 1,
#                 'CPF_NAME': 'LC08CPF_20160701_20160930_01.01',
#                 'DATA_TYPE': 'L1TP',
#                 'DATE_ACQUIRED': '2016-09-26',
#                 'DATUM': 'WGS84',
#                 'EARTH_SUN_DISTANCE': 1.0023886,
#                 'ELEVATION_SOURCE': 'GLS2000',
#                 'ELLIPSOID': 'WGS84',
#                 'FILE_DATE': 1487576173000,
#                 'GEOMETRIC_RMSE_MODEL': 6.817,
#                 'GEOMETRIC_RMSE_MODEL_X': 4.757,
#                 'GEOMETRIC_RMSE_MODEL_Y': 4.882,
#                 'GEOMETRIC_RMSE_VERIFY': 4.357,
#                 'GRID_CELL_SIZE_PANCHROMATIC': 15.0,
#                 'GRID_CELL_SIZE_REFLECTIVE': 30.0,
#                 'GRID_CELL_SIZE_THERMAL': 30.0,
#                 'GROUND_CONTROL_POINTS_MODEL': 403,
#                 'GROUND_CONTROL_POINTS_VERIFY': 103,
#                 'GROUND_CONTROL_POINTS_VERSION': 4,
#                 'IMAGE_QUALITY_OLI': 9,
#                 'IMAGE_QUALITY_TIRS': 9,
#                 'K1_CONSTANT_BAND_10': 774.8853,
#                 'K1_CONSTANT_BAND_11': 480.8883,
#                 'K2_CONSTANT_BAND_10': 1321.0789,
#                 'K2_CONSTANT_BAND_11': 1201.1442,
#                 'LANDSAT_PRODUCT_ID': 'LC08_L1TP_025031_20160926_20170220_01_T1',
#                 'LANDSAT_SCENE_ID': 'LC80250312016270LGN01',
#                 'MAP_PROJECTION': 'UTM',
#                 'NADIR_OFFNADIR': 'NADIR',
#                 'ORIENTATION': 'NORTH_UP',
#                 'PANCHROMATIC_LINES': 15601,
#                 'PANCHROMATIC_SAMPLES': 15361,
#                 'PROCESSING_SOFTWARE_VERSION': 'LPGS_2.7.0',
#                 'RADIANCE_ADD_BAND_1': -62.47995,
#                 'RADIANCE_ADD_BAND_10': 0.1,
#                 'RADIANCE_ADD_BAND_11': 0.1,
#                 'RADIANCE_ADD_BAND_2': -63.98023,
#                 'RADIANCE_ADD_BAND_3': -58.95723,
#                 'RADIANCE_ADD_BAND_4': -49.71606,
#                 'RADIANCE_ADD_BAND_5': -30.42375,
#                 'RADIANCE_ADD_BAND_6': -7.56611,
#                 'RADIANCE_ADD_BAND_7': -2.55018,
#                 'RADIANCE_ADD_BAND_8': -56.2649,
#                 'RADIANCE_ADD_BAND_9': -11.89029,
#                 'RADIANCE_MAXIMUM_BAND_1': 756.4447,
#                 'RADIANCE_MAXIMUM_BAND_10': 22.0018,
#                 'RADIANCE_MAXIMUM_BAND_11': 22.0018,
#                 'RADIANCE_MAXIMUM_BAND_2': 774.6086,
#                 'RADIANCE_MAXIMUM_BAND_3': 713.7952,
#                 'RADIANCE_MAXIMUM_BAND_4': 601.91235,
#                 'RADIANCE_MAXIMUM_BAND_5': 368.34033,
#                 'RADIANCE_MAXIMUM_BAND_6': 91.60289,
#                 'RADIANCE_MAXIMUM_BAND_7': 30.87508,
#                 'RADIANCE_MAXIMUM_BAND_8': 681.1991,
#                 'RADIANCE_MAXIMUM_BAND_9': 143.95575,
#                 'RADIANCE_MINIMUM_BAND_1': -62.46745,
#                 'RADIANCE_MINIMUM_BAND_10': 0.10033,
#                 'RADIANCE_MINIMUM_BAND_11': 0.10033,
#                 'RADIANCE_MINIMUM_BAND_2': -63.96743,
#                 'RADIANCE_MINIMUM_BAND_3': -58.94544,
#                 'RADIANCE_MINIMUM_BAND_4': -49.70612,
#                 'RADIANCE_MINIMUM_BAND_5': -30.41766,
#                 'RADIANCE_MINIMUM_BAND_6': -7.5646,
#                 'RADIANCE_MINIMUM_BAND_7': -2.54967,
#                 'RADIANCE_MINIMUM_BAND_8': -56.25364,
#                 'RADIANCE_MINIMUM_BAND_9': -11.88791,
#                 'RADIANCE_MULT_BAND_1': 0.012496,
#                 'RADIANCE_MULT_BAND_10': 0.0003342,
#                 'RADIANCE_MULT_BAND_11': 0.0003342,
#                 'RADIANCE_MULT_BAND_2': 0.012796,
#                 'RADIANCE_MULT_BAND_3': 0.011791,
#                 'RADIANCE_MULT_BAND_4': 0.0099432,
#                 'RADIANCE_MULT_BAND_5': 0.0060847,
#                 'RADIANCE_MULT_BAND_6': 0.0015132,
#                 'RADIANCE_MULT_BAND_7': 0.00051004,
#                 'RADIANCE_MULT_BAND_8': 0.011253,
#                 'RADIANCE_MULT_BAND_9': 0.0023781,
#                 'REFLECTANCE_ADD_BAND_1': -0.1,
#                 'REFLECTANCE_ADD_BAND_2': -0.1,
#                 'REFLECTANCE_ADD_BAND_3': -0.1,
#                 'REFLECTANCE_ADD_BAND_4': -0.1,
#                 'REFLECTANCE_ADD_BAND_5': -0.1,
#                 'REFLECTANCE_ADD_BAND_6': -0.1,
#                 'REFLECTANCE_ADD_BAND_7': -0.1,
#                 'REFLECTANCE_ADD_BAND_8': -0.1,
#                 'REFLECTANCE_ADD_BAND_9': -0.1,
#                 'REFLECTANCE_MAXIMUM_BAND_1': 1.2107,
#                 'REFLECTANCE_MAXIMUM_BAND_2': 1.2107,
#                 'REFLECTANCE_MAXIMUM_BAND_3': 1.2107,
#                 'REFLECTANCE_MAXIMUM_BAND_4': 1.2107,
#                 'REFLECTANCE_MAXIMUM_BAND_5': 1.2107,
#                 'REFLECTANCE_MAXIMUM_BAND_6': 1.2107,
#                 'REFLECTANCE_MAXIMUM_BAND_7': 1.2107,
#                 'REFLECTANCE_MAXIMUM_BAND_8': 1.2107,
#                 'REFLECTANCE_MAXIMUM_BAND_9': 1.2107,
#                 'REFLECTANCE_MINIMUM_BAND_1': -0.09998,
#                 'REFLECTANCE_MINIMUM_BAND_2': -0.09998,
#                 'REFLECTANCE_MINIMUM_BAND_3': -0.09998,
#                 'REFLECTANCE_MINIMUM_BAND_4': -0.09998,
#                 'REFLECTANCE_MINIMUM_BAND_5': -0.09998,
#                 'REFLECTANCE_MINIMUM_BAND_6': -0.09998,
#                 'REFLECTANCE_MINIMUM_BAND_7': -0.09998,
#                 'REFLECTANCE_MINIMUM_BAND_8': -0.09998,
#                 'REFLECTANCE_MINIMUM_BAND_9': -0.09998,
#                 'REFLECTANCE_MULT_BAND_1': 2e-05,
#                 'REFLECTANCE_MULT_BAND_2': 2e-05,
#                 'REFLECTANCE_MULT_BAND_3': 2e-05,
#                 'REFLECTANCE_MULT_BAND_4': 2e-05,
#                 'REFLECTANCE_MULT_BAND_5': 2e-05,
#                 'REFLECTANCE_MULT_BAND_6': 2e-05,
#                 'REFLECTANCE_MULT_BAND_7': 2e-05,
#                 'REFLECTANCE_MULT_BAND_8': 2e-05,
#                 'REFLECTANCE_MULT_BAND_9': 2e-05,
#                 'REFLECTIVE_LINES': 7801,
#                 'REFLECTIVE_SAMPLES': 7681,
#                 'REQUEST_ID': '0501702185660_00011',
#                 'RESAMPLING_OPTION': 'CUBIC_CONVOLUTION',
#                 'RLUT_FILE_NAME': 'LC08RLUT_20150303_20431231_01_12.h5',
#                 'ROLL_ANGLE': -0.001,
#                 'SATURATION_BAND_1': 'N',
#                 'SATURATION_BAND_2': 'N',
#                 'SATURATION_BAND_3': 'N',
#                 'SATURATION_BAND_4': 'N',
#                 'SATURATION_BAND_5': 'N',
#                 'SATURATION_BAND_6': 'Y',
#                 'SATURATION_BAND_7': 'Y',
#                 'SATURATION_BAND_8': 'N',
#                 'SATURATION_BAND_9': 'N',
#                 'SCENE_CENTER_TIME': '16:47:41.3907810Z',
#                 'SENSOR_ID': 'OLI_TIRS',
#                 'SPACECRAFT_ID': 'LANDSAT_8',
#                 'STATION_ID': 'LGN',
#                 'SUN_AZIMUTH': 155.71153,
#                 'SUN_ELEVATION': 43.912224,
#                 'TARGET_WRS_PATH': 25,
#                 'TARGET_WRS_ROW': 31,
#                 'THERMAL_LINES': 7801,
#                 'THERMAL_SAMPLES': 7681,
#                 'TIRS_SSM_MODEL': 'FINAL',
#                 'TIRS_SSM_POSITION_STATUS': 'ESTIMATED',
#                 'TIRS_STRAY_LIGHT_CORRECTION_SOURCE': 'TIRS',
#                 'TRUNCATION_OLI': 'UPPER',
#                 'UTM_ZONE': 15,
#                 'WRS_PATH': 25,
#                 'WRS_ROW': 31,
#                 'google:registration_count': 11,
#                 'google:registration_offset_x': -134.46208,
#                 'google:registration_offset_y': -325.25723,
#                 'google:registration_ratio': 0.19298245,
#                 'system:asset_size': 1194835059,
#                 'system:footprint': {'coordinates': [[...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...]],
#                                      'type': 'LinearRing'},
#                 'system:index': 'LC08_025031_20160926',
#                 'system:time_start': 1474908461390},
#  'type': 'Image',
#  'version': 1537881643136969}

# %%
# Pansharpen the image using

# RGB image
rgb = image.select('B4', 'B3', 'B2').unitScale(0, 255)
gray = image.select('B8').unitScale(0, 155)

# Convert to HSV, swap in the pan band, and convert back to RGB.
huesat = rgb.rgbToHsv().select('hue', 'saturation')
upres = ee.Image.cat(huesat, gray).hsvToRgb()


# # Display before and after layers using the same vis parameters.
# from IPython.display import Image
# visparams = {'min': [20,20,20], 'max': [200,200,200]}
# url = rgb.getThumbUrl(visparams)
# Image(url=url, format='png', embed=True)

from IPython.display import Image
visparams = {'bands': 'B4,B3,B2', 
             'min':
             'max': 0.2}
url = image.getThumbUrl(visparams)
Image(url=url, format='png', embed=True)

# pansharpen image here for better viewing

# %%
visparams = {'bands': 'B4,B3,B2', 
             'min':
             'max': 0.2}
url = upres.getThumbUrl()
Image(url=url, format='png', embed=True)

# %%
template_sld =
  '<RasterSymbolizer>' +
    '<ContrastEnhancement><_enhance_/></ContrastEnhancement>' +
    '<ChannelSelection>' +
      '<RedChannel>' +
        '<SourceChannelName>B5</SourceChannelName>' +
      '</RedChannel>' +
      '<GreenChannel>' +
        '<SourceChannelName>B4</SourceChannelName>' +
      '</GreenChannel>' +
      '<BlueChannel>' +
        '<SourceChannelName>B3</SourceChannelName>' +
      '</BlueChannel>' +
    '</ChannelSelection>' +
  '</RasterSymbolizer>';
# Out:
#   File "<ipython-input-36-5e51ce7deae4>", line 1
#     template_sld =
#                   ^
# SyntaxError: invalid syntax
